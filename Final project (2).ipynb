# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we will summarize key tools, libraries, and languages used in Data Science. We will also perform a few basic arithmetic operations and demonstrate code execution within a Jupyter Notebook.

# %% [markdown]
# ## Introduction
# This notebook provides an overview of key data science concepts, including languages, libraries, tools, and arithmetic operations used in data analysis.

# %% [markdown]
# ## Data Science Languages
# Some popular languages used in data science include:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Popular libraries used by data scientists include:
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Purpose                        |
# |----------------|--------------------------------|
# | Jupyter Notebook | Interactive coding and analysis |
# | RStudio        | R programming environment       |
# | VS Code        | Code editor                     |
# | GitHub         | Version control                 |
# | Tableau        | Data visualization              |
# | Power BI       | Business intelligence           |

# %% [markdown]
# ## Arithmetic Expressions
# Below are some examples of arithmetic expressions in Python, including multiplication, addition, and time conversion.

# %%
# Multiplication and addition
a = 5
b = 10
c = a * b
d = a + b
print("Multiplication:", c)
print("Addition:", d)
# Out:
# Multiplication: 50
# Addition: 15

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
print(minutes, "minutes is equal to", hours, "hours")
# Out:
# 150 minutes is equal to 2.5 hours

# %% [markdown]
# ## Objectives
# 1. Learn about popular data science languages.
# 2. Explore common libraries used in data science.
# 3. Understand key data science tools.
# 4. Perform basic arithmetic operations in Python.
# 5. Convert time units programmatically.

# %% [markdown]
# ## Author
# Khujesta Azizi
