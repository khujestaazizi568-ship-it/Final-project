# %% [markdown]
# # Final Project: Introduction to Data Science

# %% [markdown]
# This notebook introduces basic concepts of Data Science, including languages, libraries, tools, and arithmetic examples.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn

# %% [markdown]
# ## Data Science Tools
#
# | Tool        | Purpose                   |
# |------------|---------------------------|
# | Jupyter    | Interactive notebooks      |
# | GitHub     | Version control / sharing |
# | Tableau    | Data visualization        |
# | VS Code    | Code editor               |

# %% [markdown]
# ## Arithmetic Expression Examples
# Here we will demonstrate simple arithmetic operations using Python code.

# %% [markdown]
# # Multiply and add numbers
# result = 5 * 10 + 20
# print("Result:", result)

# %%
# Convert minutes to hours
minutes = 135
hours = minutes / 60
print(minutes, "minutes is", hours, "hours")
# Out:
# 135 minutes is 2.25 hours

# %% [markdown]
# ## Objectives
# - Learn basic Data Science tools
# - Understand common Data Science languages and libraries
# - Practice arithmetic operations in Python

# %% [markdown]
# ## Author
# Kujesta Azizi
