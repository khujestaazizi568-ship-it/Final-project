# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we will summarize key tools, libraries, and languages used in Data Science. We will also perform a few basic arithmetic operations and demonstrate code execution within a Jupyter Notebook.

# %% [markdown]
# ### Data Science Languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ### Data Science Libraries
#
# Commonly used libraries for data science include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# ### Data Science Tools
#
# | Category | Tools |
# |-----------|-------------------------|
# | Data Visualization | Tableau, Power BI, Matplotlib |
# | Data Analysis | Pandas, NumPy |
# | Machine Learning | Scikit-learn, TensorFlow, Keras |
# | Big Data Processing | Apache Spark, Hadoop |

# %% [markdown]
# ### Arithmetic Expression Examples
#
# Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Objectives
#
# In this notebook, you will learn how to:
# - Identify popular languages for Data Science
# - List commonly used libraries
# - Create tables to organize tools
# - Perform arithmetic operations in code cells
# - Convert units using Python

# %% [markdown]
# ## Author
# Khujesta Azizi
